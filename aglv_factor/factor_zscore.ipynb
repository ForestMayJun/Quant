# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np

root = '/mnt/datadisk2/aglv/aglv/lab_aglv/aglv_factor/CVaR_neg_0.9_logreturn_230101_240101_r30.csv'
# print(df)
df = pd.read_csv(root)
df.replace(np.inf, 0, inplace=True)
df.replace(-np.inf, 0, inplace=True)
# df.replace(0, np.nan, inplace=True)

df = df.iloc[::-1].reset_index(drop=True)
print(df)
# df = pd.read_csv(root)
# df.replace(np.inf, 0, inplace=True)
# df.replace(-np.inf, 0, inplace=True)
# print(df)
print(df.mean(), df.std())
# Out:
#          date  SH600084  SZ002549  SH688550  SZ000006  SZ001339  SH603939  \
# 0    20230103       NaN       NaN       NaN       NaN       NaN       NaN
# 1    20230104       NaN       NaN       NaN       NaN       NaN       NaN
# 2    20230105       NaN       NaN       NaN       NaN       NaN       NaN
# 3    20230106       NaN       NaN       NaN       NaN       NaN       NaN
# 4    20230109       NaN       NaN       NaN       NaN       NaN       NaN
# ..        ...       ...       ...       ...       ...       ...       ...
# 237  20231225 -0.017971 -0.027796 -0.021121 -0.051384 -0.059826 -0.022353
# 238  20231226 -0.017971 -0.027796 -0.021121 -0.051384 -0.059826 -0.022353
# 239  20231227 -0.017971 -0.029777 -0.021362 -0.051384 -0.059826 -0.022353
# 240  20231228 -0.017971 -0.029777 -0.021362 -0.051384 -0.059826 -0.021014
# 241  20231229 -0.017971 -0.029777 -0.022155 -0.051384 -0.059826 -0.021936
#
#      SZ000406  SZ000636  SZ300294  ...  SH600340  SH603616  SH688691  \
# ...

# %%
def zscore(series):
    return (series - series.mean()) / (series.std() + 1e-10)

data = df.apply(zscore)
data['date'] = df['date']

print(df)
# Out:
#          date  SH600084  SZ002549  SH688550  SZ000006  SZ001339  SH603939  \
# 0    20230103       NaN       NaN       NaN       NaN       NaN       NaN
# 1    20230104       NaN       NaN       NaN       NaN       NaN       NaN
# 2    20230105       NaN       NaN       NaN       NaN       NaN       NaN
# 3    20230106       NaN       NaN       NaN       NaN       NaN       NaN
# 4    20230109       NaN       NaN       NaN       NaN       NaN       NaN
# ..        ...       ...       ...       ...       ...       ...       ...
# 237  20231225 -0.017971 -0.027796 -0.021121 -0.051384 -0.059826 -0.022353
# 238  20231226 -0.017971 -0.027796 -0.021121 -0.051384 -0.059826 -0.022353
# 239  20231227 -0.017971 -0.029777 -0.021362 -0.051384 -0.059826 -0.022353
# 240  20231228 -0.017971 -0.029777 -0.021362 -0.051384 -0.059826 -0.021014
# 241  20231229 -0.017971 -0.029777 -0.022155 -0.051384 -0.059826 -0.021936
#
#      SZ000406  SZ000636  SZ300294  ...  SH600340  SH603616  SH688691  \
# ...

# %%
data = data.fillna(0)
# data['date'] = df['date']
print(data.mean(),data.std())
print(data)
# Out:
# date        2.023068e+07
# SH600084    1.518528e-15
# SZ002549    1.151879e-14
# SH688550   -2.101166e-16
# SZ000006    9.606641e-16
#                 ...
# SH600215    6.973302e-17
# SZ001212    2.461759e-15
# SZ300085    1.575416e-15
# SH688361   -6.995093e-16
# SZ301200    2.101166e-16
# Length: 5179, dtype: float64 date        341.904566
# SH600084      0.935692
# SZ002549      0.935692
# SH688550      0.935692
# SZ000006      0.935692
#                ...
# SH600215      0.935692
# SZ001212      0.935692
# SZ300085      0.935692
# SH688361      0.935692
# SZ301200      0.935692
# Length: 5179, dtype: float64
#          date  SH600084  SZ002549  SH688550  SZ000006  SZ001339  SH603939  \
# 0    20230103  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1    20230104  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2    20230105  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
data.to_csv('CVaR_neg_0.9_logreturn_zs_230101_240101_r30.csv', index=False)

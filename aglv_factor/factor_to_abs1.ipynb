# %% [markdown]
# 标准化：将因子值控制在[-1,1]之间

# %%
import pandas as pd

df = pd.read_csv('/mnt/datadisk2/aglv/aglv/lab_aglv/aglv_factor/CVaR_posi_0.9_abs_230101_240601_r45.csv')

df
# Out:
#          date  SZ300663  SH688351  SH600169  SH600151  SH603721  SZ001213  \
# 0    20230103       NaN       NaN       NaN       NaN       NaN       NaN
# 1    20230104       NaN       NaN       NaN       NaN       NaN       NaN
# 2    20230105       NaN       NaN       NaN       NaN       NaN       NaN
# 3    20230106       NaN       NaN       NaN       NaN       NaN       NaN
# 4    20230109       NaN       NaN       NaN       NaN       NaN       NaN
# ..        ...       ...       ...       ...       ...       ...       ...
# 335  20240527  0.617161  0.727672  0.636697  0.708776  0.998140  0.527101
# 336  20240528  0.617161  0.661750  0.636697  0.708776  0.998140  0.527101
# 337  20240529  0.617161  0.661750  0.636697  0.708776  0.998140  0.527101
# 338  20240530  0.617161  0.661750  0.636697  0.708776  0.930554  0.527101
# 339  20240531  0.617161  0.661750  0.636697  0.708776  0.839294  0.527101
#
#      SZ301071  SZ300494  SH601858  ...  SH600359  SH600138  SZ300342  \
# ...

# %%
df = df.fillna(0)

# %%
df.mean()
# Out:
# date        2.023345e+07
# SZ300663    5.354220e-01
# SH688351    5.564161e-01
# SH600169    4.554888e-01
# SH600151    5.351065e-01
#                 ...
# SZ300942    4.620851e-01
# SZ301258    2.359764e-01
# SZ000050    4.848801e-01
# SH600130    5.078588e-01
# SH603883    5.156964e-01
# Length: 5179, dtype: float64

# %%
df.max()
# Out:
# date        20240531.0
# SZ300663           1.0
# SH688351           1.0
# SH600169           1.0
# SH600151           1.0
#                ...
# SZ300942           1.0
# SZ301258           1.0
# SZ000050           1.0
# SH600130           1.0
# SH603883           1.0
# Length: 5179, dtype: float64

# %%
df.min()
# Out:
# date        20230103.0
# SZ300663           0.0
# SH688351           0.0
# SH600169           0.0
# SH600151           0.0
#                ...
# SZ300942           0.0
# SZ301258           0.0
# SZ000050           0.0
# SH600130           0.0
# SH603883           0.0
# Length: 5179, dtype: float64

# %%
import pandas as pd

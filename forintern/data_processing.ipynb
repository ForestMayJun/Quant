# %%
import pandas as pd
import sys
import os

sys.path.append('/mnt/datadisk2/aglv/aglv/lab_aglv')
sys.path.append('/mnt/datadisk2/aglv/aglv/lab_aglv/forintern/DataDaily.cpython-38-x86_64-linux-gnu.so')
sys.path.append('utils.cpython-38-x86_64-linux-gnu.so')
from DataDaily import DataDaily

data = DataDaily(check_data=False)
u = data.universe_all
u = list(set(u).intersection(set(data.adjclose.columns)))
epsilon = 10**-10
start_date = '20230101'
end_date = '20240101'
# open_ = data.adjopen.loc[start_date:end_date, u]
close = data.adjclose.loc[start_date:end_date, u]
# close_pct = close.pct_change().fillna(0)
# Out:
# load ./data_daily.h5...

# %%
close
# Out:
# InstrumentID   SZ003003    SH688606    SZ000999   SZ002137   SZ301388  \
# date
# 20230103      12.029701  109.756200  103.995382  25.186619  24.170000
# 20230104      12.356484  109.797992  104.948303  24.493410  23.980000
# 20230105      12.989626  110.393528  104.228318  26.936149  24.230000
# 20230106      12.050125  110.686072   99.844884  24.790500  24.800000
# 20230109      12.039913  110.330840  101.433085  25.054579  25.030000
# ...                 ...         ...         ...        ...        ...
# 20231225      11.365923  122.733917  105.761166  22.050671  23.730704
# 20231226      11.202531  117.521673  104.405254  21.390471  23.413886
# 20231227      11.427195  115.399424  105.653554  21.819601  23.608065
# 20231228      11.539526  114.686348  104.512866  22.083681  24.517639
# 20231229      11.733554  116.469038  107.030989  22.908930  24.926437
#
# InstrumentID    SH600298   SH605158   SH600107   SZ002624   SH688255  ...  \
# ...

# %%
close.isna().sum().sum()
# Out:
# 54784

# %%
close = close.fillna(method='ffill')

# %%
close
# Out:
# InstrumentID   SZ003003    SH688606    SZ000999   SZ002137   SZ301388  \
# date
# 20230103      12.029701  109.756200  103.995382  25.186619  24.170000
# 20230104      12.356484  109.797992  104.948303  24.493410  23.980000
# 20230105      12.989626  110.393528  104.228318  26.936149  24.230000
# 20230106      12.050125  110.686072   99.844884  24.790500  24.800000
# 20230109      12.039913  110.330840  101.433085  25.054579  25.030000
# ...                 ...         ...         ...        ...        ...
# 20231225      11.365923  122.733917  105.761166  22.050671  23.730704
# 20231226      11.202531  117.521673  104.405254  21.390471  23.413886
# 20231227      11.427195  115.399424  105.653554  21.819601  23.608065
# 20231228      11.539526  114.686348  104.512866  22.083681  24.517639
# 20231229      11.733554  116.469038  107.030989  22.908930  24.926437
#
# InstrumentID    SH600298   SH605158   SH600107   SZ002624   SH688255  ...  \
# ...

# %%
close.isna().sum().sum()
# Out:
# 47024

# %%
# close.iloc[:,]
close.loc[:, close.isna().sum() > 0]
# Out:
# InstrumentID   SZ301429   SH603190  SH688469   SZ301373  SH600086  SZ002220  \
# date
# 20230103            NaN        NaN       NaN        NaN       NaN       NaN
# 20230104            NaN        NaN       NaN        NaN       NaN       NaN
# 20230105            NaN        NaN       NaN        NaN       NaN       NaN
# 20230106            NaN        NaN       NaN        NaN       NaN       NaN
# 20230109            NaN        NaN       NaN        NaN       NaN       NaN
# ...                 ...        ...       ...        ...       ...       ...
# 20231225      25.232817  17.035266  8.751353  94.954235       NaN       NaN
# 20231226      25.645624  16.610983  8.556485  93.668842       NaN       NaN
# 20231227      25.581123  16.570298  8.609631  94.822400       NaN       NaN
# 20231228      26.084231  16.855091  8.857645  97.129514       NaN       NaN
# 20231229      26.368036  17.017830  8.893076  97.722772       NaN       NaN
#
# ...

# %%
import numpy as np
close = close.pct_change()

# %%
close
# Out:
# InstrumentID  SZ003003  SH688606  SZ000999  SZ002137  SZ301388  SH600298  \
# date
# 20230103           NaN       NaN       NaN       NaN       NaN       NaN
# 20230104      0.027165  0.000381  0.009163 -0.027523 -0.007861  0.004092
# 20230105      0.051240  0.005424 -0.006860  0.099730  0.010425  0.005207
# 20230106     -0.072327  0.002650 -0.042056 -0.079657  0.023525 -0.037387
# 20230109     -0.000847 -0.003209  0.015907  0.010652  0.009274  0.009827
# ...                ...       ...       ...       ...       ...       ...
# 20231225     -0.013298  0.005704 -0.001220 -0.005952 -0.016102  0.006340
# 20231226     -0.014376 -0.042468 -0.012821 -0.029940 -0.013351 -0.026020
# 20231227      0.020055 -0.018058  0.011956  0.020062  0.008293  0.008999
# 20231228      0.009830 -0.006179 -0.010796  0.012103  0.038528 -0.005853
# 20231229      0.016814  0.015544  0.024094  0.037369  0.016674 -0.013737
#
# InstrumentID  SH605158  SH600107  SZ002624  SH688255  ...  SZ300269  SZ300991  \
# ...

# %%
close = close + 1
close
# Out:
# InstrumentID  SZ003003  SH688606  SZ000999  SZ002137  SZ301388  SH600298  \
# date
# 20230103           NaN       NaN       NaN       NaN       NaN       NaN
# 20230104      1.027165  1.000381  1.009163  0.972477  0.992139  1.004092
# 20230105      1.051240  1.005424  0.993140  1.099730  1.010425  1.005207
# 20230106      0.927673  1.002650  0.957944  0.920343  1.023525  0.962613
# 20230109      0.999153  0.996791  1.015907  1.010652  1.009274  1.009827
# ...                ...       ...       ...       ...       ...       ...
# 20231225      0.986702  1.005704  0.998780  0.994048  0.983898  1.006340
# 20231226      0.985624  0.957532  0.987179  0.970060  0.986649  0.973980
# 20231227      1.020055  0.981942  1.011956  1.020062  1.008293  1.008999
# 20231228      1.009830  0.993821  0.989204  1.012103  1.038528  0.994147
# 20231229      1.016814  1.015544  1.024094  1.037369  1.016674  0.986263
#
# InstrumentID  SH605158  SH600107  SZ002624  SH688255  ...  SZ300269  SZ300991  \
# ...

# %%
close = np.log(close)
close
# Out:
# InstrumentID  SZ003003  SH688606  SZ000999  SZ002137  SZ301388  SH600298  \
# date
# 20230103           NaN       NaN       NaN       NaN       NaN       NaN
# 20230104      0.026802  0.000381  0.009121 -0.027909 -0.007892  0.004083
# 20230105      0.049970  0.005409 -0.006884  0.095065  0.010371  0.005194
# 20230106     -0.075076  0.002647 -0.042966 -0.083009  0.023252 -0.038104
# 20230109     -0.000848 -0.003215  0.015781  0.010596  0.009231  0.009779
# ...                ...       ...       ...       ...       ...       ...
# 20231225     -0.013387  0.005688 -0.001220 -0.005970 -0.016233  0.006320
# 20231226     -0.014480 -0.043396 -0.012903 -0.030397 -0.013440 -0.026365
# 20231227      0.019856 -0.018223  0.011885  0.019863  0.008259  0.008959
# 20231228      0.009782 -0.006198 -0.010855  0.012030  0.037804 -0.005870
# 20231229      0.016674  0.015424  0.023808  0.036688  0.016536 -0.013832
#
# InstrumentID  SH605158  SH600107  SZ002624  SH688255  ...  SZ300269  SZ300991  \
# ...

# %%
close.fillna(0)
# Out:
# InstrumentID  SZ003003  SH688606  SZ000999  SZ002137  SZ301388  SH600298  \
# date
# 20230103      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 20230104      0.026802  0.000381  0.009121 -0.027909 -0.007892  0.004083
# 20230105      0.049970  0.005409 -0.006884  0.095065  0.010371  0.005194
# 20230106     -0.075076  0.002647 -0.042966 -0.083009  0.023252 -0.038104
# 20230109     -0.000848 -0.003215  0.015781  0.010596  0.009231  0.009779
# ...                ...       ...       ...       ...       ...       ...
# 20231225     -0.013387  0.005688 -0.001220 -0.005970 -0.016233  0.006320
# 20231226     -0.014480 -0.043396 -0.012903 -0.030397 -0.013440 -0.026365
# 20231227      0.019856 -0.018223  0.011885  0.019863  0.008259  0.008959
# 20231228      0.009782 -0.006198 -0.010855  0.012030  0.037804 -0.005870
# 20231229      0.016674  0.015424  0.023808  0.036688  0.016536 -0.013832
#
# InstrumentID  SH605158  SH600107  SZ002624  SH688255  ...  SZ300269  SZ300991  \
# ...

# %%
close.mean()
close.std()
# Out:
# InstrumentID
# SZ003003    0.017159
# SH688606    0.021301
# SZ000999    0.022702
# SZ002137    0.028375
# SZ301388    0.023055
#               ...
# SZ300093    0.038401
# SZ300075    0.035827
# SH600886    0.012791
# SZ300778    0.044450
# SZ300608    0.041361
# Length: 5178, dtype: float64
